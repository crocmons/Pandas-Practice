# %%
import pandas as pd

# %%
df = pd.read_csv('heart-disease.csv')

# %% [markdown]
# heart disease for patients records table:

# %%
df.head(12)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 1    37    1   2       130   250    0        1      187      0      3.5
# 2    41    0   1       130   204    0        0      172      0      1.4
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 7    44    1   1       120   263    0        1      173      0      0.0
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 11   48    0   2       130   275    0        1      139      0      0.2
#
#     slope  ca  thal  target
# ...

# %%
df.target.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='target'>

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ### CSV Heart Disease Data target value means who has the heart disease in Pie-Chart Format:

# %%
df.target.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### ML Frame Image

# %% [markdown]
# ![](6-step-ml-framework.png)

# %% [markdown]
# ## See all Files in jupyter notebook
# by using ls cmd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 7894-EF12
#
#  Directory of C:\Users\HP\Desktop\ml_project
#
# 01/15/2024  12:48 AM    <DIR>          .
# 01/15/2024  12:48 AM    <DIR>          ..
# 01/15/2024  12:13 AM    <DIR>          .ipynb_checkpoints
# 01/15/2024  12:34 AM           332,025 6-step-ml-framework.png
# 12/14/2023  11:12 PM    <DIR>          env
# 01/15/2024  12:13 AM            11,328 heart-disease.csv
# 01/15/2024  12:11 AM            37,910 Numpy.ipynb
# 01/15/2024  12:48 AM            43,434 Pandas.ipynb
# 12/17/2023  01:04 AM             1,768 Practice.ipynb
#                5 File(s)        426,465 bytes
#                4 Dir(s)   3,335,434,240 bytes free
